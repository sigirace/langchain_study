# %%
from langchain.llms.huggingface_hub import HuggingFaceHub
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("[INST]{word}라는 단어는 무엇을 의미하니?[/INST]")

llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    model_kwargs={
        "max_new_tokens": 250
    }
)

llm.client.api_url = 'https://api-inference.huggingface.co/models/mistralai/Mistral-7B-Instruct-v0.1'

chain = prompt | llm

chain.invoke({
    "word": "감자"
})
# Out:
# ' 감자는 식품으로 식사를 향상시키는 맛을 추가하는 것을 의미합니다. 감자는 식품에 맛을 추가하는 데 사용되는 다양한 식품으로 넘치며, 식품에 맛을 추가하는 데 사용되는 가장 중요한 역할을 합니다. 감자는 식품에 맛을 추가하는 데 사용되는 다양한 식품으로 넘치며, 식품에 맛을 추가하는 데 사용되는 가장 중요한 역할을 합니다. 감자는 식품에 맛을 추가하는 데 사용되는 다양한 식품으로 넘치며, 식품에 맛을 추가하는'
