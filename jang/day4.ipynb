# %%
# create api key 할떄 'Make calls to the serverless Inference API' 체크해줘야함
# HuggingFaceHub를 통해 무료로 llm을 사용 할 수 있다.(물론 제한은 있음)
# Instruct 모델은 format을 안따르면 답이 형편없게 나온다는데 ?
from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("[INST]What is the meaning of {word}[/INST]")

llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    model_kwargs={
        "max_new_tokens": 250,
    },
)

chain = prompt | llm

chain.invoke({"word": "potato"})
# Out:
# '[INST]What is the meaning of potato[/INST] A potato is a starchy vegetable that is native to South America. It is one of the most widely consumed crops in the world, and is grown for its edible tubers. Potatoes are usually boiled, baked, fried, or roasted, and can be served as a side dish, or used as a main ingredient in various dishes such as stews, soups, and casseroles. They are rich in carbohydrates, fiber, and various vitamins and minerals, making them an important source of nutrition for many people around the world.'

# %%
# 8.2 HuggingFacePipeline
# 설치된 model이 로컬에 설치된다는데 어디에 설치되는지 못찾음
from langchain.llms.huggingface_pipeline import HuggingFacePipeline
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("A {word} is a")

llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    #device =-1 # 0이면 GPU -1이면 CPU
    pipeline_kwargs={"max_new_tokens": 150},
)

chain = prompt | llm
# Out:
# ...
# Using pad_token, but it is not set yet.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'A tomato is a common food crop used to cover crops such as sugar cane and potato. Some tomatoes grow in tightly packed containers that are tightly packed with nutrients such as vitamin C, a vitamin E-rich vitamin, and vitamin K. One tomato cultivar that is considered a "tomato bean," and its seeds will be harvested and harvested to produce the seeds of a tomato.\n\n\nThe process, which requires the aid of many enzymes and enzymes, requires considerable weight (25, 25-28). This weight is also used to make water, so tomatoes will need to stay healthy, be harvested well ahead, and be prepared well prior to harvest. This can be difficult to do, as harvesting is very, very time consuming and expensive. The cost of producing a'

# %%
# 8.3 GPT4All
from langchain.llms.gpt4all import GPT4All
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "You are a helpful assistant that defines words. Define this word: {word}."
)

llm = GPT4All(
    model="./falcon.bin",
)

chain = prompt | llm

chain.invoke({"word": "tomato"})

# %%
# 8.4 Ollama
# 03_PrivateGPT.py에 코드있음
# ollama run llama3.1
# ollama list / ollama ls
